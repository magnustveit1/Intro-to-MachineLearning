# %% [markdown]
# # Land Cover Classification Framework
#
# The workflow will cover how to retrieve LandSat Imagery to begin development of a landcover classifier. We will use the landcover classifier to examine changes over time.
#
# ## Case Application: Great Salt Lake
#
# The Great Salt Lake (GSL) fluctuates both from natural seasonality, year-to-year climate anomolies, and anthropogentic water use (e.g., diversions, growth, development). In today's example, we will retrieve LandSat imagery and develop a land cover classifier to examine the changes in area of the GSL over time.

# %%
from utils import getLandSat, plotting
import ee
import rasterio
import matplotlib.pyplot as plt
from IPython.display import Image, display
# Out:
# /uufs/chpc.utah.edu/common/home/u0972368/conda-envs/hyriver/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/drive%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=omRGm5IiB3kLU7gARakJqBrDlyIjZtBMd2Xs9uoJLpw&tc=X98OBmRJuJ7g-O2w1bR_6ErrDRWMFBCwQiGQD0momSc&cc=q436DTtsw77a8ENOINkUtALuxNSQ_D1ArV1W-gTpzYk>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/drive%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=omRGm5IiB3kLU7gARakJqBrDlyIjZtBMd2Xs9uoJLpw&tc=X98OBmRJuJ7g-O2w1bR_6ErrDRWMFBCwQiGQD0momSc&cc=q436DTtsw77a8ENOINkUtALuxNSQ_D1ArV1W-gTpzYk</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Unable to connect to VS Code server: Error in request.
# Error: connect ENOENT /run/user/1819237/vscode-ipc-5f337eda-2d69-4f6c-bc21-bd447cca9c47.sock
#     at PipeConnectWrap.afterConnect [as oncomplete] (node:net:1637:16) {
#   errno: -2,
#   code: 'ENOENT',
#   syscall: 'connect',
#   address: '/run/user/1819237/vscode-ipc-5f337eda-2d69-4f6c-bc21-bd447cca9c47.sock'
# }
# Successfully saved authorization token.
# Earth Engine initialized successfully.

# %% [markdown]
# ### LandSat Data Retrievel
#
# Use the data retrievel functions to collect LandSat Imagery of the GSL

# %%
# Define the bounding box for the region of interest (ROI), we can get these coordinates from Google Earth or any GIS software. The coordinates are in the format [xmin, ymin, xmax, ymax].
xmin = -113.2
xmax = -111.95
ymin = 40.5
ymax = 41.85

# # Get the ROI as a GeoJSON object
roi = getLandSat.get_bbox([xmin, ymin, xmax, ymax])

#call the getLandSat function to download the data for the specified ROI and time range
getLandSat.export_monthly_range_parallel( #This function parallelizes the download of Landsat data for a specified region of interest (ROI) and time range, allowing for faster data retrieval.
    roi=roi,                         #roi: The region of interest defined as a GeoJSON object, specifying the area for which the Landsat data will be downloaded.
    output_dir="data/LandSat/GSL",   #output_dir: The directory where the downloaded Landsat data will be saved. In this case, it is set to "data/LandSat/GSL".
    start_year=1985,                 #start_year: The starting year of the time range for which the Landsat data will be downloaded. In this case, it is set to 1985.
    end_year=2025,                   #end_year: The ending year of the time range for which the Landsat data will be downloaded. In this case, it is set to 2025.
    max_workers=3,                   #max_workers: The maximum number of worker threads to use for parallel processing. In this case, it is set to 3, which means that up to 3 threads will be used to download the data concurrently.
    months_before=2,                 #months_before: The number of months before the specified start year to include in the download. In this case, it is set to 2, which means that data from 2 months before the start year (1985) will also be included in the download.
    months_after=2,                  #months_after: The number of months after the specified end year to include in the download. In this case, it is set to 2, which means that data from 2 months after the end year (2025) will also be included in the download.
    reducer="median"                 #reducer: The method used to aggregate the Landsat data when multiple images are available for the same time period. In this case, it is set to "median", which means that the median value of the available images will be used for each pixel in the output data.
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Prepared 492 monthly jobs
# Generating URL ...
# Generating URL ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/8ac8e5dd59a2a8d25231aa93ea360f4d-a6ee2f27fce2337a086b3ad34be11539:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/81603fe4e40c43f9a7c35e217afb4e73-5add77fbaa4f5e78f3880597c73b76fa:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/ef27978442fe6224374353ebabab7531-29c9bdb82f94b15c77f75a53cf914d3d:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_01.tif
# Saved to data/LandSat/GSL/GSL_1985_01.tif
# Finished: data/LandSat/GSL/GSL_1985_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/5d28f03245b81340af1f3a22d81ce7ea-0d2f4cd03c0c79fad6448a8dd4330b34:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_03.tif
# Saved to data/LandSat/GSL/GSL_1985_03.tif
# Finished: data/LandSat/GSL/GSL_1985_03.tif
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_02.tif
# Saved to data/LandSat/GSL/GSL_1985_02.tif
# Finished: data/LandSat/GSL/GSL_1985_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/276394ee0b1f984bf42ff59a0e98bb5d-1fdb58bae92654b7346ea8da6bbd8249:getPixels
# Please wait ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/055eb2db23da8bea2cf4c59a64fa44a5-b177e566bb0043e358cd3997aefa1998:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_04.tif
# Saved to data/LandSat/GSL/GSL_1985_04.tif
# Finished: data/LandSat/GSL/GSL_1985_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/c623f313cee69a58168755caddd84753-084ab498ba43602e7cf8a1b99a59a835:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_06.tif
# Saved to data/LandSat/GSL/GSL_1985_06.tif
# Finished: data/LandSat/GSL/GSL_1985_06.tif
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_05.tif
# Saved to data/LandSat/GSL/GSL_1985_05.tif
# Finished: data/LandSat/GSL/GSL_1985_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/0be2c76626b8143aa0ca491e2165c667-88dc9b17cfaaef7b9efdb67b208ffdfc:getPixels
# Please wait ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/3aadc850a5257fa9c1b012bff85b4ad0-e893f7258491965fa63cbf1fbd88d2f4:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_07.tif
# Saved to data/LandSat/GSL/GSL_1985_07.tif
# Finished: data/LandSat/GSL/GSL_1985_07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/2a3838acc20aa72acaaacd0f3ca38038-80adb6690b0bd737a48a171ae546be9e:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_08.tif
# Saved to data/LandSat/GSL/GSL_1985_08.tif
# Finished: data/LandSat/GSL/GSL_1985_08.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/4d5126fbea70615369fef0fcfc56b564-1b5a54e8daed08db3b0766ec0adf0720:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_09.tif
# Saved to data/LandSat/GSL/GSL_1985_09.tif
# Finished: data/LandSat/GSL/GSL_1985_09.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/d0c1d43901d1bb680bf4ec985d23e610-965ae5db2850138acb96c5503c14341b:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_10.tif
# Saved to data/LandSat/GSL/GSL_1985_10.tif
# Finished: data/LandSat/GSL/GSL_1985_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/f54154dc869a9e7611d592b4cd580386-1f15601293c15768237ad2bfcc96e203:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_11.tif
# Saved to data/LandSat/GSL/GSL_1985_11.tif
# Finished: data/LandSat/GSL/GSL_1985_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/90b92b2291246861ecf2b197a623a210-b1aaa4c1f958d26070ebffc9b586f9a0:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_12.tif
# Saved to data/LandSat/GSL/GSL_1985_12.tif
# Finished: data/LandSat/GSL/GSL_1985_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/e8e88afd6b31ff3455cda53a57879c17-4ec524836d4aa31b5a5d542eea4892c0:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_01.tif
# Saved to data/LandSat/GSL/GSL_1986_01.tif
# Finished: data/LandSat/GSL/GSL_1986_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/251c68e70403ef37146ab9d21e4e4737-a88f5082b70c1d8086c09c4b96731f32:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_02.tif
# Saved to data/LandSat/GSL/GSL_1986_02.tif
# Finished: data/LandSat/GSL/GSL_1986_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/0d94c3f8398d158d237605f4f804900f-5483057c82f29bf570e14333aac0c15c:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_03.tif
# Saved to data/LandSat/GSL/GSL_1986_03.tif
# Finished: data/LandSat/GSL/GSL_1986_03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/31d5666e8657421cd4855606075adb87-cf4f2cef1f7e40a59511f71e030c3593:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_04.tif
# Saved to data/LandSat/GSL/GSL_1986_04.tif
# Finished: data/LandSat/GSL/GSL_1986_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/40598051e7b80146e0f97647bc1743e0-578dd8ae11cc2cb63932907a1092a2ac:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_06.tif
# Saved to data/LandSat/GSL/GSL_1986_06.tif
# Finished: data/LandSat/GSL/GSL_1986_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/b16d46ee7e52e80b96022d7a944acf20-e00cbe49931c5772b04a6130b814fa53:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_05.tif
# Saved to data/LandSat/GSL/GSL_1986_05.tif
# Finished: data/LandSat/GSL/GSL_1986_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/7e9b726d37a62537116de1dfaf38d3de-b5a377cd3510d69eaeba5dac8c36de82:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_07.tif
# Saved to data/LandSat/GSL/GSL_1986_07.tif
# Finished: data/LandSat/GSL/GSL_1986_07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/7d9ffce35fa0a6f3c3fac6b25ddacb06-af371f4a666b74eef4ad89507286d8df:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_08.tif
# Saved to data/LandSat/GSL/GSL_1986_08.tif
# Finished: data/LandSat/GSL/GSL_1986_08.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/2853e9a6d8a53c3106251ba6cdcae067-e1b13c30d4869c2071bc2618fd2f3ba4:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_09.tif
# Saved to data/LandSat/GSL/GSL_1986_09.tif
# Finished: data/LandSat/GSL/GSL_1986_09.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/3b16862cd6217576c8b420330aed2d82-5fcdd450eb695d32a12add722fa27252:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_11.tif
# Saved to data/LandSat/GSL/GSL_1986_11.tif
# Finished: data/LandSat/GSL/GSL_1986_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/6615d513fd2069b7c24bd3b40a8accfa-a5159aef66a63bd5efa1bb9cfb85477c:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_12.tif
# Saved to data/LandSat/GSL/GSL_1986_12.tif
# Finished: data/LandSat/GSL/GSL_1986_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/f0c223931f9037d3b155f5bfa6ed111d-3f6c7e95c10e09a20b521812b71411fc:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_10.tif
# Saved to data/LandSat/GSL/GSL_1986_10.tif
# Finished: data/LandSat/GSL/GSL_1986_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/51160944ff0879dc80df7403bb035c60-c7dd7af97832f25e91f03a34c74a9577:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1987_02.tif
# Saved to data/LandSat/GSL/GSL_1987_02.tif
# Finished: data/LandSat/GSL/GSL_1987_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/da97f61966ae4a9514b608d2262a4ccb-08b21ba5fef825b11182b7c16701a07b:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1987_01.tif
# Saved to data/LandSat/GSL/GSL_1987_01.tif
# Finished: data/LandSat/GSL/GSL_1987_01.tif
# Generating URL ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1987
:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1988_05.tif
# Saved to data/LandSat/GSL/GSL_1988_05.tif
# Finished: data/LandSat/GSL/GSL_1988_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/077bece37cc006fd9f501b3b3e429597-8790a73019ccdf55c20397b6e506b0c8:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1988_07.tif
# Saved to data/LandSat/GSL/GSL_1988_07.tif
# Finished: data/LandSat/GSL/GSL_1988_07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/40f8ae42b17c33e2c0b4747debb4051c-27a152a1b5061371040c1570ab1ce0c4:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1988_06.tif
# Saved to data/LandSat/GSL/GSL_1988_06.tif
# Finished: data/LandSat/GSL/GSL_1988_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/c3f71199d705013b2b3859e829cee591-df498a15708c02c886eb0312c1e720e9:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1988_10.tif
# Saved to data/LandSat/GSL/GSL_1988_10.tif
# Finished: data/LandSat/GSL/GSL_1988_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/88d18b2778809b7248ac62867f38f8e6-7e4b0004b79c845468a9eb0e9d5526f9:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1988_08.tif
# Saved to data/LandSat/GSL/GSL_1988_08.tif
# Finished: data/LandSat/GSL/GSL_1988_08.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/594b622dfdb947f1a970bc71f3c2cdf0-0d506f328e7438788d0f57c142c12cc3:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1988_09.tif
# Saved to data/LandSat/GSL/GSL_1988_09.tif
# Finished: data/LandSat/GSL/GSL_1988_09.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/c8d21ccd8bbbb39ac96363042f8af851-db6580967593371a99b3c3e88f3ebcee:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1988_12.tif
# Saved to data/LandSat/GSL/GSL_1988_12.tif
# Finished: data/LandSat/GSL/GSL_1988_12.tif
# Generating URL ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1988_11.tif
# Saved to data/LandSat/GSL/GSL_1988_11.tif
# Finished: data/LandSat/GSL/GSL_1988_11.tif
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/43884f3fa276025207baf1f2656d64db-70460391a6667193f4124343aa940e6c:getPixels
# Please wait ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/c86689cc2affda58bd1dafe27f1c8af3-b993c10a7a674d2dc18360655973ff72:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_01.tif
# Saved to data/LandSat/GSL/GSL_1989_01.tif
# Finished: data/LandSat/GSL/GSL_1989_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/c8d9da1b5dc14fab6374567aed4dde28-03a26b2fbaadc727a47ec6e9797af8c8:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_02.tif
# Saved to data/LandSat/GSL/GSL_1989_02.tif
# Finished: data/LandSat/GSL/GSL_1989_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/0a8c486c1f54bd8f6312564371d1b9db-3d00752f0b43827545777b5c6dd7616c:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_03.tif
# Saved to data/LandSat/GSL/GSL_1989_03.tif
# Finished: data/LandSat/GSL/GSL_1989_03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/c5df72231245530f8b5b06cf16eb381a-b54d8082a84cb9d643b3c1be714c763e:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_04.tif
# Saved to data/LandSat/GSL/GSL_1989_04.tif
# Finished: data/LandSat/GSL/GSL_1989_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/f277a9878ee2e8379850a428e6fdd3b0-a6de788365f8eb3d5aa3ac758ea8fe4a:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_06.tif
# Saved to data/LandSat/GSL/GSL_1989_06.tif
# Finished: data/LandSat/GSL/GSL_1989_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/2a2ec0f8f7b4b46f6e3627806f964fd5-b532c2939a974ff27b432e38872cc7d2:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_05.tif
# Saved to data/LandSat/GSL/GSL_1989_05.tif
# Finished: data/LandSat/GSL/GSL_1989_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/aab626bb04b5a83776a5f290d4604d0d-40ac9a7ecf3e92a7240b4256be68361a:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_07.tif
# Saved to data/LandSat/GSL/GSL_1989_07.tif
# Finished: data/LandSat/GSL/GSL_1989_07.tif
# Generating URL ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_09.tif
# Saved to data/LandSat/GSL/GSL_1989_09.tif
# Finished: data/LandSat/GSL/GSL_1989_09.tif
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/1d8fefa68059922b0543eaba7d151a0e-d083b61b6bc513f838c283147253400a:getPixels
# Please wait ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/3906c412629f7052f23a6ecb2529aac7-26e2004802ff8c3d775434826585ceee:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_08.tif
# Saved to data/LandSat/GSL/GSL_1989_08.tif
# Finished: data/LandSat/GSL/GSL_1989_08.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/1d665121b56b0c0cfca83f0ad54dd860-43c723afafb51c70af9592a584f601bb:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_12.tif
# Saved to data/LandSat/GSL/GSL_1989_12.tif
# Finished: data/LandSat/GSL/GSL_1989_12.tif
# No images for 1989-11-01 to 1990-04-01
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/d5b1d07e9513ea3cc8e269528d809158-239df1b9dda66f8aca3d17ef9c53d6cb:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_10.tif
# Saved to data/LandSat/GSL/GSL_1989_10.tif
# Finished: data/LandSat/GSL/GSL_1989_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/7c8fdb8d1056f8d91e3d94b4ee170049-0bad86334e663e41238323209a172315:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_11.tif
# Saved to data/LandSat/GSL/GSL_1989_11.tif
# Finished: data/LandSat/GSL/GSL_1989_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/5c5b48ac9678b096ba68810203339b19-013373ea33aabc25a35b6e0d351cd14e:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_02.tif
# Saved to data/LandSat/GSL/GSL_1990_02.tif
# Finished: data/LandSat/GSL/GSL_1990_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/272df565a1de2c5e4fe98e3549bac4c2-51eab0ebdad5d9d2b808b848941ac2e1:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_03.tif
# Saved to data/LandSat/GSL/GSL_1990_03.tif
# Finished: data/LandSat/GSL/GSL_1990_03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/cace9a7767e6a1db09ea5274c39d1468-a73b85ce06dbff832fa74ea6ece5c59c:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_04.tif
# Saved to data/LandSat/GSL/GSL_1990_04.tif
# Finished: data/LandSat/GSL/GSL_1990_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/1cd17620d88bc3dce08a8bd55cced672-c9ff2a6ff26eaa2b5eddd5b6cd3b7835:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_05.tif
# Saved to data/LandSat/GSL/GSL_1990_05.tif
# Finished: data/LandSat/GSL/GSL_1990_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/24a88216b62ead00a66abd9cb31b1153-f38d0121d80ffe7cb7b459babefe0851:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_06.tif
# Saved to data/LandSat/GSL/GSL_1990_06.tif
# Finished: data/LandSat/GSL/GSL_1990_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/e3c16cb6cfcdcd213de5fd55c0178d5c-99c70ff49a678c6bd92deff7276227df:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_07.tif
# Saved to data/LandSat/GSL/GSL_1990_07.tif
# Finished: data/LandSat/GSL/GSL_1990_07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/e5d25460aa1d90db6236ae6f7e11c33c-da86cc8a692c5a770bd13950703e45cd:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_08.tif
# Saved to data/LandSat/GSL/GSL_1990_08.tif
# Finished: data/LandSat/GSL/GSL_1990_08.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/572b000a21ff883622fd30f1cd32a7e2-81746316274596a9813d296dcf632ae9:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_09.tif
# Saved to data/LandSat/GSL/GSL_1990_09.tif
# Finished: data/LandSat/GSL/GSL_1990_09.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/5a89d7b14d1c71e803366d925b5bc4bf-ca73cd5fe7a54c52b2dcd5fcc0a84e34:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_10.tif
# Saved to data/LandSat/GSL/GSL_1990_10.tif
# Finished: data/LandSat/GSL/GSL_1990_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/02ba928031c9163199cfe90b0c1dcff1-729cf8700bf08fab22e5c553b86be354:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990
getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1993_03.tif
# Saved to data/LandSat/GSL/GSL_1993_03.tif
# Finished: data/LandSat/GSL/GSL_1993_03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/353c549dd4e0425124c16f48755f0376-c132bbd409bb462de87a5fe706e216b7:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1993_05.tif
# Saved to data/LandSat/GSL/GSL_1993_05.tif
# Finished: data/LandSat/GSL/GSL_1993_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/450f5df869ceabfcf5379a3631667961-9402f20c551d50c13618b0d2620ace93:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1993_06.tif
# Saved to data/LandSat/GSL/GSL_1993_06.tif
# Finished: data/LandSat/GSL/GSL_1993_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/4a713fd483fe5f318c142a992ee543dd-da71a725be6be554e093ecf0906c7607:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1993_07.tif
# Saved to data/LandSat/GSL/GSL_1993_07.tif
# Finished: data/LandSat/GSL/GSL_1993_07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/c1bfec78c1be52ff8902ac54f79c4360-394ac818a5c38fc7248997f9990f2199:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1993_08.tif
# Saved to data/LandSat/GSL/GSL_1993_08.tif
# Finished: data/LandSat/GSL/GSL_1993_08.tif
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1993_09.tif
# Saved to data/LandSat/GSL/GSL_1993_09.tif
# Finished: data/LandSat/GSL/GSL_1993_09.tif
# Generating URL ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/14f67bc21e85c18ddcd56a2625d09116-63874cc055873599f5551237e2c29700:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/e6862828ce0dae81755b867490581856-bfefc740e6aa7043eca144477513b556:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1993_10.tif
# Saved to data/LandSat/GSL/GSL_1993_10.tif
# Finished: data/LandSat/GSL/GSL_1993_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/4a57ad56222a2d5b858c8a325e6503e5-bcd0b3a563da5a83dfc5534d835da422:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1993_11.tif
# Saved to data/LandSat/GSL/GSL_1993_11.tif
# Finished: data/LandSat/GSL/GSL_1993_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/6ece1b481427bbd77f43c5dac2dac121-9a5a7aed31902df87f336ceb00ac9a60:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1993_12.tif
# Saved to data/LandSat/GSL/GSL_1993_12.tif
# Finished: data/LandSat/GSL/GSL_1993_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/1320e86655929eab6275eee363e486b2-34bd5a800b2f9d472540ead22a5e4b9f:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1994_02.tif
# Saved to data/LandSat/GSL/GSL_1994_02.tif
# Finished: data/LandSat/GSL/GSL_1994_02.tif
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1994_01.tif
# Saved to data/LandSat/GSL/GSL_1994_01.tif
# Finished: data/LandSat/GSL/GSL_1994_01.tif
# Generating URL ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/6a3667472e47e4c91e98044db77cf9f4-bf6cc1e3f0d03c498b13b15a9d6a5bca:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/2ad8e6b2c16d391e769245229e56f78b-8875f17a143fecfcc0800f3b4758fef5:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1994_03.tif
# Saved to data/LandSat/GSL/GSL_1994_03.tif
# Finished: data/LandSat/GSL/GSL_1994_03.tif
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1994_05.tif
# ...
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2022_10.tif
# Saved to data/LandSat/GSL/GSL_2022_10.tif
# Finished: data/LandSat/GSL/GSL_2022_10.tif
# Generating URL ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2022_11.tif
# Saved to data/LandSat/GSL/GSL_2022_11.tif
# Finished: data/LandSat/GSL/GSL_2022_11.tif
# Generating URL ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2022_12.tif
# Saved to data/LandSat/GSL/GSL_2022_12.tif
# Finished: data/LandSat/GSL/GSL_2022_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/8b002d0496782122d57a0be80da39188-1cde1022cfc6dfe86cb5592973af853e:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_01.tif
# Saved to data/LandSat/GSL/GSL_2023_01.tif
# Finished: data/LandSat/GSL/GSL_2023_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/0ee793e4c93062db0c9f373d27d5b05a-c604d2a13c46e1e6c2976e2d858ef779:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/4c9fe9e5d1cc3f90b999dbc5d018aea7-fd035094c169d7338e621d81144d006c:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/b6c8480a95c143ab63db5955a42b7238-202071cc80b706e200d615f610d5c181:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_02.tif
# Saved to data/LandSat/GSL/GSL_2023_02.tif
# Finished: data/LandSat/GSL/GSL_2023_02.tif
# Generating URL ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_03.tif
# Saved to data/LandSat/GSL/GSL_2023_03.tif
# Finished: data/LandSat/GSL/GSL_2023_03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/e56125e720f635d1bde3a8cd9e98ddb9-94779f429fee8b3925a3b087db7e627a:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/e7313cff162bd60af1ff370d46621cb2-453cc0099640a7c45deae19ce2beae69:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_04.tif
# Saved to data/LandSat/GSL/GSL_2023_04.tif
# Finished: data/LandSat/GSL/GSL_2023_04.tif
# Generating URL ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_05.tif
# Saved to data/LandSat/GSL/GSL_2023_05.tif
# Finished: data/LandSat/GSL/GSL_2023_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/57d2120d14632e4a0f76bef10d036891-d825e7f8692fd4a6dce68eba37208d15:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_06.tif
# Saved to data/LandSat/GSL/GSL_2023_06.tif
# Finished: data/LandSat/GSL/GSL_2023_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/e2d751a37343387a02eaef3e67910707-788aa19ea643c7bf4e3f3d5c41a7fc91:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/4f621b40eccf3b56e58d84442177ceaf-3d24c8a96bdad2380b8d39791bf33eda:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_07.tif
# Saved to data/LandSat/GSL/GSL_2023_07.tif
# Finished: data/LandSat/GSL/GSL_2023_07.tif
# Generating URL ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_09.tif
# Saved to data/LandSat/GSL/GSL_2023_09.tif
# Finished: data/LandSat/GSL/GSL_2023_09.tif
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_08.tif
# Saved to data/LandSat/GSL/GSL_2023_08.tif
# Finished: data/LandSat/GSL/GSL_2023_08.tif
# Generating URL ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/5b8d081ce3f150b606ddb067871585f6-8046b3050c43a593cf57fcf8c32ea5fc:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/c2cadc34dca565710f846a0665e5f0d4-f21b8334d712c0c251dd23f93e3d4012:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/fa5ee7bc795f95f5fdaf581ff98242c2-21ed095a029771919a69a76274a1368c:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_10.tif
# Saved to data/LandSat/GSL/GSL_2023_10.tif
# Finished: data/LandSat/GSL/GSL_2023_10.tif
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_12.tif
# Saved to data/LandSat/GSL/GSL_2023_12.tif
# Finished: data/LandSat/GSL/GSL_2023_12.tif
# Generating URL ...
# Generating URL ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_11.tif
# Saved to data/LandSat/GSL/GSL_2023_11.tif
# Finished: data/LandSat/GSL/GSL_2023_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/9f44be7e3185b2e0db326246a8d7534b-2807f33cdda06ee9cc289675dd71c669:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/40b794813a7dc3ed07328e069062e695-40b484af4c84627ff4fa94c7750a527d:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/4a59c5d1659a90cefbfbd6a45460aec2-a3df188bd78490da80acc0c5d85e91bf:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_01.tif
# Saved to data/LandSat/GSL/GSL_2024_01.tif
# Finished: data/LandSat/GSL/GSL_2024_01.tif
# Generating URL ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_03.tif
# Saved to data/LandSat/GSL/GSL_2024_03.tif
# Finished: data/LandSat/GSL/GSL_2024_03.tif
# Generating URL ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_02.tif
# Saved to data/LandSat/GSL/GSL_2024_02.tif
# Finished: data/LandSat/GSL/GSL_2024_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/d0632a0d69f64a31b240c1630f210cb3-2988481dce17dd1dd6cd7ce1b0b43f01:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/af0d52fd6176e6c1b1e0231378937d32-9d9906df9cef840bd9945b18f136ea3b:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/361194170de79d0866ba7123f61b4b10-8e51635881adb810c832b1b85c615a7d:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_04.tif
# Saved to data/LandSat/GSL/GSL_2024_04.tif
# Finished: data/LandSat/GSL/GSL_2024_04.tif
# Generating URL ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_05.tif
# Saved to data/LandSat/GSL/GSL_2024_05.tif
# Finished: data/LandSat/GSL/GSL_2024_05.tif
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_06.tif
# Saved to data/LandSat/GSL/GSL_2024_06.tif
# Finished: data/LandSat/GSL/GSL_2024_06.tif
# Generating URL ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/aad3a437665e28c50e44288f0badb6b3-5c72614d3085f5a40f3e99efe5bf7835:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/3130349b736c9f392172be367f038dfc-7b9e35634049c152416a1c9213079479:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/954f64567fc2f5d038cdd217811cb66e-8648b3d564c247de6fa65c15ff8cb6b0:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_08.tif
# Saved to data/LandSat/GSL/GSL_2024_08.tif
# Finished: data/LandSat/GSL/GSL_2024_08.tif
# Generating URL ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_07.tif
# Saved to data/LandSat/GSL/GSL_2024_07.tif
# Finished: data/LandSat/GSL/GSL_2024_07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/9b22055e6fd833ee78c81acd6b354388-fd3b8b18672a351c60c638ea9f7db86b:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/35bc83edd0f3a306c93b56fac29bb1d1-5b024c4b1260e1f08e2e90b30ce728c1:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_09.tif
# Saved to data/LandSat/GSL/GSL_2024_09.tif
# Finished: data/LandSat/GSL/GSL_2024_09.tif
# Generating URL ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_10.tif
# Saved to data/LandSat/GSL/GSL_2024_10.tif
# Finished: data/LandSat/GSL/GSL_2024_10.tif
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/35a57574720d1caa231c8c4d5f465d09-bef7acde597d2aea16395bc143735091:getPixels
# Please wait ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/e1c5a2e592203f06a74634aa94dff483-a746afdbeebee4f2d654daa60ec03d2f:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_11.tif
# Saved to data/LandSat/GSL/GSL_2024_11.tif
# Finished: data/LandSat/GSL/GSL_2024_11.tif
# Generating URL ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_12.tif
# Saved to data/LandSat/GSL/GSL_2024_12.tif
# Finished: data/LandSat/GSL/GSL_2024_12.tif
# Generating URL ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_01.tif
# Saved to data/LandSat/GSL/GSL_2025_01.tif
# Finished: data/LandSat/GSL/GSL_2025_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/1bfbf3f7ddb64773a46366ed7f954094-298396e058652a130edbd4a6a231962b:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/ab0bd30c6497e74f896712eed98a78fd-ecdd3f3f7b8c7a49826aaa01e23accad:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_02.tif
# Saved to data/LandSat/GSL/GSL_2025_02.tif
# Finished: data/LandSat/GSL/GSL_2025_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/6ea8b7aee4777081a326da5045258c0f-f56b96a997cfd5d7ac1c886d1de685e0:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_03.tif
# Saved to data/LandSat/GSL/GSL_2025_03.tif
# Finished: data/LandSat/GSL/GSL_2025_03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/22566157608b104eb115f7b719da7941-5a32f80104c878830212a4030a610464:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_04.tif
# Saved to data/LandSat/GSL/GSL_2025_04.tif
# Finished: data/LandSat/GSL/GSL_2025_04.tif
# Generating URL ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_05.tif
# Saved to data/LandSat/GSL/GSL_2025_05.tif
# Finished: data/LandSat/GSL/GSL_2025_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/a45178ba0f9728feb40ac505740d9689-46209bba8def440c504710c4e64920c8:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/c4aa4b1e8e96a4068abf1a4ea357327d-30b4a361ca86994638b468e9f0ff61ee:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_07.tif
# Saved to data/LandSat/GSL/GSL_2025_07.tif
# Finished: data/LandSat/GSL/GSL_2025_07.tif
# Generating URL ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_06.tif
# Saved to data/LandSat/GSL/GSL_2025_06.tif
# Finished: data/LandSat/GSL/GSL_2025_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/16bca781112dfb001a43aead1dff5e1f-903f391d0331ea7541751b0f554cf3a6:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/74245ccf5abc1aef55fb20e8b7bae626-48371e7495c40444cf61bda885be26dd:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/7dfb9b31ead04054bed1c9ddbed7d7f8-f92202cfa6d1470a5b3ece5b93ee38a6:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_09.tif
# Saved to data/LandSat/GSL/GSL_2025_09.tif
# Finished: data/LandSat/GSL/GSL_2025_09.tif
# Generating URL ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_08.tif
# Saved to data/LandSat/GSL/GSL_2025_08.tif
# Finished: data/LandSat/GSL/GSL_2025_08.tif
# Generating URL ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_10.tif
# Saved to data/LandSat/GSL/GSL_2025_10.tif
# Finished: data/LandSat/GSL/GSL_2025_10.tif
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/50fc0a75d6191634d39a160dc07cab10-6daed56b090a2c77c3ebe51105ecdf1b:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/177221847440/thumbnails/aeb517b7ac911cf2e8392c15379f410e-95cd46b00897ca1e47305ab8b35710d8:getPixels
# Please wait ...
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_11.tif
# Saved to data/LandSat/GSL/GSL_2025_11.tif
# Finished: data/LandSat/GSL/GSL_2025_11.tif
# Data downloaded to /uufs/chpc.utah.edu/common/home/u0972368/Hydroinformatics/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_12.tif
# Saved to data/LandSat/GSL/GSL_2025_12.tif
# Finished: data/LandSat/GSL/GSL_2025_12.tif
# All monthly exports completed.

# %% [markdown]
# ## Plot some images
#
# We want to plot some of the images to double check out work.
# * How does the image look?
# * Is the bounding box correct?
# * How is the color scaling?

# %%
Path = 'data/LandSat/GSL/' #The directory where the downloaded Landsat data is saved. In this case, it is set to "data/LandSat/GSL/".
date = '1986_01' #The specific date for which the Landsat image will be plotted. In this case, it is set to '1986_01', which likely corresponds to January 1986.

# This function call for plotting the Landsat image for the specified date using the data stored in the specified directory. The function reads the relevant Landsat data from the directory, processes it, and then generates a visual representation of the image for the given date.
plotting.plot_landsat_image(Path, date)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Exploring changes over time
#
# A key element of the exercise is to quantitatively describe changes in GSL surface area over time. A first step is to qualitaively do this by making a time-series gif of the images and visually assess if we in fact do observed changes.

# %%
plotting.make_gif_from_tifs(
    input_dir="data/LandSat/GSL",
    output_gif="data/LandSat/GSL/gsl_timelapse.gif",
    frame_duration=.8,
    max_width=400,
    font_size=40
)

display(Image(filename="data/LandSat/GSL/gsl_timelapse.gif"))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Building GIF:   0%|          | 0/485 [00:00<?, ?frame/s]
# Saving GIF to data/LandSat/GSL/gsl_timelapse.gif with frame duration 0.8s...
# Saved GIF to data/LandSat/GSL/gsl_timelapse.gif

# %% [markdown]
# ### Lets trainsition to model development
#
# Now that we have the data, we can start developing it to train our ML model in [LC_Classifier](LC_Classifier.ipynb)
